# %% [markdown]
# ![data meaning.jpg](<attachment:data meaning.jpg>)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_columns' , 26)

# %%
df = pd.read_csv(r"/content/drive/MyDrive/Colab Notebooks/final_internship_data.csv")
df
# Out:
#          User ID          User Name       Driver Name Car Condition Weather  \
# 0       KHVrEVlD     Kimberly Adams        Amy Butler     Very Good   windy
# 1       lPxIuEri       Justin Tapia  Hannah Zimmerman     Excellent  cloudy
# 2       gsVN8JLS    Elizabeth Lopez    Amanda Jackson           Bad  stormy
# 3       9I7kWFgd      Steven Wilson          Amy Horn     Very Good  stormy
# 4       8QN5ZaGN  Alexander Andrews  Cassandra Larson           Bad  stormy
# ...          ...                ...               ...           ...     ...
# 499995  er7Luy6J       Morgan Smith   Gabriel Coleman           Bad   rainy
# 499996  FWDZu9NA     Dillon Jackson    Larry Richards     Very Good   rainy
# 499997  QZIMcpLZ  Michael Rodriguez    Lonnie Santana           Bad   rainy
# 499998  AD72Uwmn       Deborah Soto      Emily Rivera          Good  stormy
# 499999  qGKn4Um5         Eric Jones        Julie King     Very Good   sunny
#
# ...

# %%
df.dtypes
# Out:
# User ID               object
# User Name             object
# Driver Name           object
# Car Condition         object
# Weather               object
# Traffic Condition     object
# key                   object
# fare_amount          float64
# pickup_datetime       object
# pickup_longitude     float64
# pickup_latitude      float64
# dropoff_longitude    float64
# dropoff_latitude     float64
# passenger_count        int64
# hour                   int64
# day                    int64
# month                  int64
# weekday                int64
# year                   int64
# jfk_dist             float64
# ewr_dist             float64
# lga_dist             float64
# sol_dist             float64
# nyc_dist             float64
# distance             float64
# bearing              float64
# dtype: object

# %%
df.columns
# Out:
# Index(['User ID', 'User Name', 'Driver Name', 'Car Condition', 'Weather',
#        'Traffic Condition', 'key', 'fare_amount', 'pickup_datetime',
#        'pickup_longitude', 'pickup_latitude', 'dropoff_longitude',
#        'dropoff_latitude', 'passenger_count', 'hour', 'day', 'month',
#        'weekday', 'year', 'jfk_dist', 'ewr_dist', 'lga_dist', 'sol_dist',
#        'nyc_dist', 'distance', 'bearing'],
#       dtype='object')

# %%
df_useful = df[[ 'Car Condition', 'Weather',
       'Traffic Condition' , 'fare_amount', 'pickup_datetime',
       'pickup_longitude', 'pickup_latitude', 'dropoff_longitude',
       'dropoff_latitude', 'passenger_count', 'hour', 'day', 'month',
       'weekday', 'year', 'jfk_dist', 'ewr_dist', 'lga_dist', 'sol_dist',
       'nyc_dist', 'distance', 'bearing']]
df_useful
# Out:
#        Car Condition Weather  Traffic Condition  fare_amount  \
# 0          Very Good   windy  Congested Traffic          4.5
# 1          Excellent  cloudy       Flow Traffic         16.9
# 2                Bad  stormy  Congested Traffic          5.7
# 3          Very Good  stormy       Flow Traffic          7.7
# 4                Bad  stormy  Congested Traffic          5.3
# ...              ...     ...                ...          ...
# 499995           Bad   rainy      Dense Traffic          7.0
# 499996     Very Good   rainy       Flow Traffic         13.7
# 499997           Bad   rainy       Flow Traffic         25.0
# 499998          Good  stormy  Congested Traffic          6.5
# 499999     Very Good   sunny       Flow Traffic          4.9
#
#             pickup_datetime  pickup_longitude  pickup_latitude  \
# 0       2009-06-15 17:26:21         -1.288826         0.710721
# 1       2010-01-05 16:52:16         -1.291824         0.710546
# ...

# %%
df_useful.describe()
# Out:
#          fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# count  500000.000000     500000.000000    500000.000000      499995.000000
# mean       11.358361         -1.265712         0.696740          -1.265755
# std         9.916617          0.206941         0.140909           0.205903
# min       -44.900000        -52.119764       -54.389440         -59.049665
# 25%         6.000000         -1.291405         0.710958          -1.291393
# 50%         8.500000         -1.291226         0.711268          -1.291197
# 75%        12.500000         -1.290970         0.711520          -1.290908
# max       500.000000         37.360538        29.724576           0.712985
#
#        dropoff_latitude  passenger_count           hour            day  \
# count     499995.000000    500000.000000  500000.000000  500000.000000
# mean           0.696675         1.683428      13.510834      15.684206
# std            0.128997         1.307395       6.511571       8.681066
# ...

# %%
df_useful.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 22 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Car Condition      500000 non-null  object
#  1   Weather            500000 non-null  object
#  2   Traffic Condition  500000 non-null  object
#  3   fare_amount        500000 non-null  float64
#  4   pickup_datetime    500000 non-null  object
#  5   pickup_longitude   500000 non-null  float64
#  6   pickup_latitude    500000 non-null  float64
#  7   dropoff_longitude  499995 non-null  float64
#  8   dropoff_latitude   499995 non-null  float64
#  9   passenger_count    500000 non-null  int64
#  10  hour               500000 non-null  int64
#  11  day                500000 non-null  int64
#  12  month              500000 non-null  int64
#  13  weekday            500000 non-null  int64
#  14  year               500000 non-null  int64
# ...

# %%
df_useful.isna().sum()
# Out:
# Car Condition        0
# Weather              0
# Traffic Condition    0
# fare_amount          0
# pickup_datetime      0
# pickup_longitude     0
# pickup_latitude      0
# dropoff_longitude    5
# dropoff_latitude     5
# passenger_count      0
# hour                 0
# day                  0
# month                0
# weekday              0
# year                 0
# jfk_dist             5
# ewr_dist             5
# lga_dist             5
# sol_dist             5
# nyc_dist             5
# distance             5
# bearing              5
# dtype: int64

# %%
df_useful[df_useful['dropoff_longitude'].isna()]
# Out:
#        Car Condition Weather  Traffic Condition  fare_amount  \
# 120227     Very Good   rainy      Dense Traffic         12.5
# 245696           Bad   windy      Dense Traffic         86.5
# 340533     Excellent  cloudy      Dense Traffic         27.5
# 428108     Very Good  cloudy       Flow Traffic         11.8
# 471472          Good   windy  Congested Traffic          7.8
#
#             pickup_datetime  pickup_longitude  pickup_latitude  \
# 120227  2012-12-11 12:57:00         -1.291417         0.711101
# 245696  2013-03-21 18:07:07         -1.291397         0.711057
# 340533  2012-12-11 12:50:52         -1.291188         0.711828
# 428108  2011-09-08 09:12:52         -1.291317         0.711249
# 471472  2012-12-11 12:34:20          0.000000         0.000000
#
#         dropoff_longitude  dropoff_latitude  passenger_count  hour  day  \
# 120227                NaN               NaN                0    12   11
# ...

# %%
df_useful = df_useful.dropna()
df_useful.isna().sum()
# Out:
# Car Condition        0
# Weather              0
# Traffic Condition    0
# fare_amount          0
# pickup_datetime      0
# pickup_longitude     0
# pickup_latitude      0
# dropoff_longitude    0
# dropoff_latitude     0
# passenger_count      0
# hour                 0
# day                  0
# month                0
# weekday              0
# year                 0
# jfk_dist             0
# ewr_dist             0
# lga_dist             0
# sol_dist             0
# nyc_dist             0
# distance             0
# bearing              0
# dtype: int64

# %%
len(df_useful[df_useful['fare_amount']<=1])
# Out:
# 40

# %%
df_useful[df_useful['distance'] == 0]
# Out:
#        Car Condition Weather  Traffic Condition  fare_amount  \
# 11               Bad   rainy      Dense Traffic          5.5
# 15         Excellent   windy      Dense Traffic          5.0
# 26              Good  cloudy  Congested Traffic          6.5
# 105        Very Good   sunny       Flow Traffic         52.0
# 124        Very Good   rainy       Flow Traffic          8.0
# ...              ...     ...                ...          ...
# 499724          Good  cloudy       Flow Traffic          7.0
# 499882     Excellent   rainy      Dense Traffic          4.0
# 499913          Good   sunny      Dense Traffic          4.9
# 499938     Very Good   rainy       Flow Traffic          6.9
# 499985     Excellent   sunny       Flow Traffic         10.9
#
#             pickup_datetime  pickup_longitude  pickup_latitude  \
# 11      2012-12-24 11:24:00          0.000000         0.000000
# 15      2013-11-23 12:57:00          0.000000         0.000000
# ...

# %%
len(df_useful[df_useful['distance'] == 0])
# Out:
# 14250

# %%
len(df_useful[df_useful['passenger_count'] < 1])
# Out:
# 1791

# %%
len( df_useful[ df_useful['distance'] > 100 ] )
# Out:
# 1092

# %%
pd.DataFrame(df_useful['passenger_count'].value_counts())
# Out:
#                   count
# passenger_count
# 1                346009
# 2                 73908
# 5                 35322
# 3                 21761
# 4                 10614
# 6                 10590
# 0                  1791

# %%
# Get the indexes of rows to drop
indexes_to_drop = df_useful[ (df_useful['fare_amount'] < 1) |
                            (df_useful['passenger_count'] < 1) |
                            (df_useful['distance'] == 0 ) |
                            (df_useful['distance'] > 100)
                            ].index

# %%
# Drop those rows using their indexes
df_1 = df_useful.drop(indexes_to_drop)

# %%
df_1.describe()
# Out:
#          fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# count  482869.000000     482869.000000    482869.000000      482869.000000
# mean       11.352267         -1.289965         0.710163          -1.289948
# std         9.738031          0.047018         0.046537           0.047020
# min         2.500000         -2.118676        -1.291826          -2.118677
# 25%         6.000000         -1.291409         0.710987          -1.291396
# 50%         8.500000         -1.291231         0.711281          -1.291205
# 75%        12.500000         -1.290993         0.711527          -1.290939
# max       450.000000          0.712319         7.000225           0.712985
#
#        dropoff_latitude  passenger_count           hour            day  \
# count     482869.000000    482869.000000  482869.000000  482869.000000
# mean           0.710157         1.690521      13.512334      15.681168
# std            0.045647         1.306464       6.510065       8.681184
# ...

# %%
df_1.shape
# Out:
# (482869, 22)

# %%
#    function to Creates a boxplot for each column in the DataFrame.

def plot_boxplot_per_column(df):

    # Loop through each column in the DataFrame
    for column in df.columns:
        # Check if the column contains numeric data
        if pd.api.types.is_numeric_dtype(df[column]):
            plt.figure(figsize=(8, 6))
            df.boxplot(column=column , vert=False)
            plt.title(f'Boxplot of {column}')
            # plt.ylabel(column)
            plt.xticks([])
            plt.show()

# %%
plot_boxplot_per_column(df_1)

# %%
def calculate_outliers(df):

    # function to Calculate the number of outliers and their percentage for each numeric column in the DataFrame.

    outlier_info = []

    for column in df.columns:
        # Ensure the column contains numeric data
        if pd.api.types.is_numeric_dtype(df[column]):
            Q1 = df[column].quantile(0.25)
            Q3 = df[column].quantile(0.75)
            IQR = Q3 - Q1

            # Determine outliers using the IQR method
            lower_bound = Q1 - 1.5 * IQR
            upper_bound = Q3 + 1.5 * IQR
            outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)][column]

            # Calculate the number and percentage of outliers
            num_outliers = outliers.count()
            total_values = df[column].count()
            percent_outliers = (num_outliers / total_values) * 100

            # Store the results
            outlier_info.append({
                'Column': column,
                'Number of Outliers': num_outliers,
                'Percentage of Outliers': percent_outliers,
                'Lower Bound': lower_bound,
                'Upper Bound': upper_bound
            })

    return pd.DataFrame(outlier_info)

# %%
# Calculate outliers
outlier_stats = calculate_outliers(df_1)
print(outlier_stats)
# Out:
#                Column  Number of Outliers  Percentage of Outliers  \
# 0         fare_amount               41740                8.644166
# 1    pickup_longitude               23739                4.916240
# 2     pickup_latitude               14741                3.052795
# 3   dropoff_longitude               27131                5.618708
# 4    dropoff_latitude               22256                4.609118
# 5     passenger_count               54828               11.354632
# 6                hour                   0                0.000000
# 7                 day                   0                0.000000
# 8               month                   0                0.000000
# 9             weekday                   0                0.000000
# 10               year                   0                0.000000
# 11           jfk_dist               50268               10.410277
# 12           ewr_dist               18994                3.933572
# ...

# %%
def plot_outliers(outlier_info):
    """
    Plot the number of outliers for each numeric column using a bar plot with a 'Blues' color palette.
    """
    # Sort outlier_info by the number of outliers
    outlier_info_sorted = outlier_info.sort_values(by='Number of Outliers', ascending=False)

    # Plot
    plt.figure(figsize=(12, 6))
    sns.barplot(
        x='Column',
        y='Number of Outliers',
        data=outlier_info_sorted,
        palette='Blues'
    )
    plt.title('Number of Outliers in Each Numeric Column')
    plt.xlabel('Columns')
    plt.ylabel('Number of Outliers')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %%
plot_outliers(outlier_stats)
# Out:
# <ipython-input-56-a7ce74823744>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
def outlier_handler(series):
    Q1 = series.quantile(0.25)
    Q3 = series.quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return lower_bound, upper_bound

# %%
for col in df_1.columns:
    if df_1[col].dtype in ['float64', 'int64', 'int32']:
        # Calculate lower and upper bounds for the column
        lower_bound, upper_bound = outlier_handler(df_1[col])

        # Drop rows that are outliers
        df_1 = df_1[(df_1[col] >= lower_bound) & (df_1[col] <= upper_bound)]

# %%
# Scatter plot
plt.figure(figsize=(12, 8))
sns.scatterplot(data=df_1, x='distance', y='fare_amount', color='Skyblue', s=100, alpha=0.7, edgecolor='k')
plt.title('Scatter Plot of Fare Amount vs. Distance')
plt.xlabel('Distance (miles)')
plt.ylabel('Fare Amount ($)')
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %%
plot_boxplot_per_column(df_1)

# %%
#Group by each day
rides_by_weekday = df_1.groupby('weekday').size()

#Plot rides by weekday
plt.figure(figsize=(10, 6))
sns.barplot(x=rides_by_weekday.index, y=rides_by_weekday.values, palette='Blues')
plt.title('Number of Rides by Day of the Week')
plt.xlabel('Day of the Week')
plt.ylabel('Number of Rides')
plt.xticks(ticks=range(7), labels=['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])
plt.show()


#Group by each hour in the day
rides_by_hour = df_1.groupby('hour').size()

# Plot rides by hour with a sequential palette
plt.figure(figsize=(10, 6))
sns.barplot(x=rides_by_hour.index, y=rides_by_hour.values, palette='Blues')
plt.title('Number of Rides by Hour of the Day')
plt.xlabel('Hour of the Day')
plt.ylabel('Number of Rides')
plt.show()

#Group by Traffic Condition in the day
rides_by_traffic = df_1.groupby('Traffic Condition').size()

# Plot rides by hour with a sequential palette
plt.figure(figsize=(10, 6))
sns.barplot(x=rides_by_traffic.index, y=rides_by_traffic.values, palette='Blues')
plt.title('Number of Rides by Traffic Condition')
plt.xlabel('Traffic Condition')
plt.ylabel('Number of Rides')
plt.show()


# Plot the relationship between traffic condition and fare amount
plt.figure(figsize=(12, 8))
sns.violinplot(x='Traffic Condition', y='fare_amount', data=df_1, palette='Blues')
plt.title('Fare Amount by Traffic Condition')
plt.xlabel('Traffic Condition')
plt.ylabel('Fare Amount')
plt.show()
# Out:
# <ipython-input-30-0dc3044ce8d2>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=rides_by_weekday.index, y=rides_by_weekday.values, palette='Blues')
# <ipython-input-30-0dc3044ce8d2>:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=rides_by_hour.index, y=rides_by_hour.values, palette='Blues')
# <ipython-input-30-0dc3044ce8d2>:30: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=rides_by_traffic.index, y=rides_by_traffic.values, palette='Blues')
# <ipython-input-30-0dc3044ce8d2>:39: FutureWarning:
#
# ...

# %%
# Group by each day and mean the fare amounts
total_fare_by_weekday = df_1.groupby('weekday')['fare_amount'].mean()

# Plot total fare by weekday
plt.figure(figsize=(10, 6))
sns.barplot(x=total_fare_by_weekday.index, y=total_fare_by_weekday.values, palette='Blues')
plt.title('Avagere Fare Amount by Day of the Week')
plt.xlabel('Day of the Week')
plt.ylabel('Avagere Fare Amount ($)')
plt.xticks(ticks=range(7), labels=['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])
plt.show()
# Out:
# <ipython-input-38-1fafa56e40b5>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=total_fare_by_weekday.index, y=total_fare_by_weekday.values, palette='Blues')

# %%
# Group by each hour and mean the fare amounts
total_fare_by_hour = df_1.groupby('hour')['fare_amount'].mean()

# Plot total fare by hour
plt.figure(figsize=(10, 6))
sns.barplot(x=total_fare_by_hour.index, y=total_fare_by_hour.values, palette='Blues')
plt.title('Avagere Fare Amount by Hour of the Day')
plt.xlabel('Hour of the Day')
plt.ylabel('Avagere Fare Amount ($)')
plt.show()
# Out:
# <ipython-input-37-137763a84f33>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=total_fare_by_hour.index, y=total_fare_by_hour.values, palette='Blues')

# %%
#Group by each day
rides_by_day = df_1.groupby('day').size()

#Plot rides by day
plt.figure(figsize=(10, 6))
sns.barplot(x=rides_by_day.index, y=rides_by_day.values, palette='Blues')
plt.title('Number of Rides by Day of the Month ')
plt.xlabel('Day of the Month')
plt.ylabel('Number of Rides')
plt.show()
# Out:
# <ipython-input-44-a7a55e6b1564>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=rides_by_day.index, y=rides_by_day.values, palette='Blues')

# %%
# Group by each hour and mean the fare amounts
total_fare_by_day = df_1.groupby('day')['fare_amount'].mean()

# Plot total fare by hour
plt.figure(figsize=(10, 6))
sns.barplot(x=total_fare_by_day.index, y=total_fare_by_day.values, palette='Blues')
plt.title('Avagere Fare Amount by Hour of the Day')
plt.xlabel('Day')
plt.ylabel('Avagere Fare Amount ($)')
plt.show()
# Out:
# <ipython-input-42-30b3c9cb7c92>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=total_fare_by_day.index, y=total_fare_by_day.values, palette='Blues')

# %%
# Group by each month and mean the fare amounts
total_fare_by_month = df_1.groupby('month')['fare_amount'].mean()

# Plot total fare by month
plt.figure(figsize=(10, 6))
sns.barplot(x=total_fare_by_month.index, y=total_fare_by_month.values, palette='Blues')
plt.title('Avagere Fare Amount by Month ')
plt.xlabel('Month')
plt.ylabel('Avagere Fare Amount ($)')
plt.show()
# Out:
# <ipython-input-45-6602282c6b66>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=total_fare_by_month.index, y=total_fare_by_month.values, palette='Blues')

# %%
#Group by each day
rides_by_month = df_1.groupby('month').size()

#Plot rides by month
plt.figure(figsize=(10, 6))
sns.barplot(x=rides_by_month.index, y=rides_by_month.values, palette='Blues')
plt.title('Number of Rides by Month ')
plt.xlabel('Month')
plt.ylabel('Number of Rides')
plt.show()
# Out:
# <ipython-input-47-f8edb88b536d>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=rides_by_month.index, y=rides_by_month.values, palette='Blues')

# %%
# # Extract the year from 'pickup_datetime'
# df['year'] = df['pickup_datetime'].dt.year

# Group by the 'year' column and count the number of rides
rides_per_year = df_1.groupby('year').size().reset_index(name='number_of_rides')
plt.figure(figsize=(10, 6))
sns.barplot(x=rides_per_year['year'], y=rides_per_year['number_of_rides'], palette='Blues')
plt.title('Number of Rides per Year')
plt.xlabel('Year')
plt.ylabel('Number of Rides')
plt.show()
# Out:
# <ipython-input-52-4d37d77b1e60>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=rides_per_year['year'], y=rides_per_year['number_of_rides'], palette='Blues')

# %%
# Group by each month and mean the fare amounts
total_fare_by_year = df_1.groupby('year')['fare_amount'].mean()

# Plot total fare by year
plt.figure(figsize=(10, 6))
sns.barplot(x=total_fare_by_year.index, y=total_fare_by_year.values, palette='Blues')
plt.title('Avagere Fare Amount by Year ')
plt.xlabel('Year')
plt.ylabel('Avagere Fare Amount ($)')
plt.show()
# Out:
# <ipython-input-53-8c99d1b0b744>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=total_fare_by_year.index, y=total_fare_by_year.values, palette='Blues')

# %%
#Group by Weather Condition in the day
rides_by_Weather = df_1.groupby('Weather').size()

# Plot rides by hour with a sequential palette
plt.figure(figsize=(10, 6))
sns.barplot(x=rides_by_Weather.index, y=rides_by_Weather.values, palette='Blues')
plt.title('Number of Rides by Weather Condition')
plt.xlabel('Weather Condition')
plt.ylabel('Number of Rides')
plt.show()
# Out:
# <ipython-input-54-2ca62e62af1c>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=rides_by_Weather.index, y=rides_by_Weather.values, palette='Blues')

# %%
# Group by each month and mean the fare amounts
total_fare_by_Weather = df_1.groupby('Weather')['fare_amount'].mean()

# Plot total fare by Weather
plt.figure(figsize=(10, 6))
sns.barplot(x=total_fare_by_Weather.index, y=total_fare_by_Weather.values, palette='Blues')
plt.title('Avagere Fare Amount by Weather Condition ')
plt.xlabel('Weather Condition')
plt.ylabel('Avagere Fare Amount ($)')
plt.show()
# Out:
# <ipython-input-55-999fcf0ea0e9>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=total_fare_by_Weather.index, y=total_fare_by_Weather.values, palette='Blues')

# %%
# Group by 'passenger_count' and calculate the mean fare amount
average_fare_by_passenger_count = df_1.groupby('passenger_count')['fare_amount'].mean()

# Plot average fare by passenger count
plt.figure(figsize=(10, 6))
sns.barplot(x=average_fare_by_passenger_count.index, y=average_fare_by_passenger_count.values, palette='Blues')
plt.title('Average Fare Amount by Passenger Count')
plt.xlabel('Passenger Count')
plt.ylabel('Average Fare Amount ($)')
plt.show()
# Out:
# <ipython-input-58-f84e4ea008ea>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=average_fare_by_passenger_count.index, y=average_fare_by_passenger_count.values, palette='Blues')
